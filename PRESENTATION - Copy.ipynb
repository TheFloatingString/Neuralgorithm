# %% [markdown]
# # Le cerveau en algorithme

# %% [markdown]
# Projet d'Expo-Sciences 2018, présenté par Laurence Liang, étudiant en quatrième secondaire au Collège Jean-de-Brébeuf

# %% [markdown]
# ### L'activité de circuits neuronaux

# %%
# %matplotlib notebook

plot_3d_neurons(X)
# Out:
# <img src="data:image/png;base64,..." width="1132.8045373716897">

# %% [markdown]
# ### Visualisation de l'activité de ces neurones

# %%
# %matplotlib notebook
total_pca(X,y_tar, labeling=2)
# Out:
# <img src="data:image/png;base64,..." width="712">

# %% [markdown]
# ### Activité des neurones individuels

# %%
plot_n_activity()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Performacne de SVM et de mon algorithme inspiré du cerveau

# %%
# %matplotlib notebook
demo_implement_svm(X, y_tar)
# Out:
# Combien d'exemples de testage? 200
# Quelle époque? (Résultats sont à 50% chance de 0 à 11) 37
#
# Données normalisées
# Entraînement complété
# <img src="data:image/png;base64,..." width="639.2025602824718">
# Taux de précision: 94 %

# %% [markdown]
# ### Prédictions du réseau neuronal artificiel

# %%
# %matplotlib notebook
predictions_du_reseau(predictions, validations, blank=True)
# Out:
# <img src="data:image/png;base64,..." width="766">

# %% [markdown]
# ### Performance de mon algorithme inspiré du cerveau sur l'identification de chiffres écrits

# %%
# %matplotlib notebook
digit_clf.predict_image(random_=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Je vois un 1!

# %% [markdown]
# ### Performance de mon algorithme inspiré du cerveau à identifier des types de tumeurs

# %%
num = int(input("Combien de patients? "))
for i in range(num):
    n = 0
    while True:
        rand = random.randrange(0,569)
        if ca['target'][rand]==i%2:
            n=rand
            break
    fig = plt.figure()
    ax = plt.subplot(1,1,1)
    plt.title("Données d'un patient")
    coldict = {0:'purple', 1:'blue'}
    plt.barh(feature_names, ca['data'][n], color=coldict[i%2])
    ax.set_xscale('log')
    plt.grid()
    plt.xlim(0.0005,2500)
    plt.xlabel("Mesure")
    plt.show()
    cclf.fit(ca['data'][n], ca['target'][n])
# Out:
# Combien de patients? 2
# Prédiction: maligne
# Vraie réponse: maligne
# Prédiction: benigne
# Vraie réponse: benigne

# %% [markdown]
# ### Démonstration de mon réseau neuronal artificiel

# %%
keras_model = ModelKeras(n_tasks=399, session=2, n_epochs=140)

normalized_data = max_abs_scaler.fit_transform(n_model.X[0])
decoding_target_rmsprop = keras_model.run_session(normalized_data , optimizer_var='SGD', epoch_var=200, batch_size_var=3, session=1, n_tasks=301, start=0, end=1)
# Out:
# 15
# 15
# C:\ProgramData\Anaconda3\lib\site-packages\keras\models.py:942: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 12 samples, validate on 3 samples
# Epoch 1/200
# 12/12 [==============================] - 1s 114ms/step - loss: 0.1771 - acc: 0.0833 - val_loss: 0.1602 - val_acc: 0.0000e+00
# Epoch 2/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1770 - acc: 0.0833 - val_loss: 0.1601 - val_acc: 0.0000e+00
# Epoch 3/200
# 12/12 [==============================] - 0s 920us/step - loss: 0.1770 - acc: 0.0833 - val_loss: 0.1600 - val_acc: 0.0000e+00
# Epoch 4/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1769 - acc: 0.0833 - val_loss: 0.1600 - val_acc: 0.0000e+00
# Epoch 5/200
# 12/12 [==============================] - 0s 985us/step - loss: 0.1768 - acc: 0.0833 - val_loss: 0.1599 - val_acc: 0.0000e+00
# Epoch 6/200
# ...
